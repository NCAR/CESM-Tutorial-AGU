# %% [markdown]
# # Full CESM tutorial

# %% [markdown]
# Access the complete CESM Tutorial materials here:
#
# [Open the full CESM Tutorial webpage](https://ncar.github.io/CESM-Tutorial/README.html)
#
#
# ___
