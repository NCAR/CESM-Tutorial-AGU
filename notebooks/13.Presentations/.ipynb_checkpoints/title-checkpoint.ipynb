# %% [markdown]
# # Presentations

# %% [markdown]
# This shared Google Drive folder contains the slides of the oral presentations from the tutorial.
#
# [Shared Google Drive](https://drive.google.com/drive/folders/1t2Se4dixIix5iWH25Lh5sZ8SvbKDr_3p?usp=sharing)
