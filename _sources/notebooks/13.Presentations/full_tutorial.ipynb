# %% [markdown]
# # Full CESM tutorial

# %% [markdown]
# We offer a more comprehensive, week-long CESM Tutorial each year:
#
# [Learn more about the annual CESM Tutorial](https://www.cesm.ucar.edu/events/tutorials)
#
# You can also access the complete tutorial materials online:
#
# [Explore the full CESM Tutorial](https://ncar.github.io/CESM-Tutorial/README.html)
#
# These resources will help you deepen your knowledge and take your CESM skills to the next level.
#
# ___
