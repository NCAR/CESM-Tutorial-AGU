# %% [markdown]
# # Presentations

# %% [markdown]
# This shared Google Drive folder contains the slides from the oral presentations given during the tutorial.
#
# [Shared Google Drive](https://drive.google.com/drive/folders/1t2Se4dixIix5iWH25Lh5sZ8SvbKDr_3p?usp=sharing)
#
# The materials will remain available online after the tutorial ends, so you can revisit them at any time.
#
#
#
# ___
